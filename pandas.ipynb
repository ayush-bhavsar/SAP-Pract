# %%
import pandas as pd

# %%
### read csv file

df = pd.read_csv("airlines.csv")
df
# Out:
#      Airport.Code                                       Airport.Name  \
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 1844          MDW          Chicago, IL: Chicago Midway International
# 1845          MIA                     Miami, FL: Miami International
# 1846          MSP  Minneapolis, MN: Minneapolis-St Paul Internati...
# 1847          ORD          Chicago, IL: Chicago O'Hare International
# 1848          PDX               Portland, OR: Portland International
#
#      Time.Label  Month Time.Month Name  Time.Year  \
# 0       2003/06      6            June       2003
# ...

# %%
### sliccing the csv data

df[0:20:5]
# Out:
#    Airport.Code                                       Airport.Name Time.Label  \
# 0           ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 5           DEN                   Denver, CO: Denver International    2003/06
# 10          IAD    Washington, DC: Washington Dulles International    2003/06
# 15          LGA                            New York, NY: LaGuardia    2003/06
#
#     Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0       6            June       2003                            1009
# 5       6            June       2003                             516
# 10      6            June       2003                             320
# 15      6            June       2003                             302
#
#     Statistics.# of Delays.Late Aircraft  \
# 0                                   1275
# 5                                    323
# 10                                   295
# 15                                   338
#
# ...

# %%
### to string

# print(df.to_string())

# %%
### list to Series

a = [1 , 5 , 9] ### list
new_a = pd.Series(a) ### series

new_a
# Out:
# 0    1
# 1    5
# 2    9
# dtype: int64

# %%
new_a[2]
# Out:
# np.int64(9)

# %%
### dictionary to Series

b = {
    "name" : "Ayush",
    "age" : "20",
    "Univeristy" : "Iar"
}

new_b = pd.Series(b)
new_b
# Out:
# name          Ayush
# age              20
# Univeristy      Iar
# dtype: object

# %%
### converting the Dictionary into DataFrame

data = {
    'DOB' : [1402 , 2505 , 1205],
    'age' : [18 , 19 , 25]
}

DataFrame_Data = pd.DataFrame(data)
DataFrame_Data
# Out:
#     DOB  age
# 0  1402   18
# 1  2505   19
# 2  1205   25

# %%
DataFrame_Data.loc[0]
# Out:
# DOB    1402
# age      18
# Name: 0, dtype: int64

# %%
DataFrame_Data.loc[1]
# Out:
# DOB    2505
# age      19
# Name: 1, dtype: int64

# %%
airlines = pd.read_csv("airlines.csv")

# %%
### displays the Row Data for [Start , Stop , Step]
airlines.loc[0:1]
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
#
#    Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0      6            June       2003                            1009
# 1      6            June       2003                             374
#
#    Statistics.# of Delays.Late Aircraft  \
# 0                                  1275
# 1                                   495
#
#    Statistics.# of Delays.National Aviation System  \
# 0                                             3217
# 1                                              685
#
#    Statistics.# of Delays.Security  ...  Statistics.Flights.Delayed  \
# 0                               17  ...                        5843
# 1                                3  ...                        1623
#
# ...

# %%
### var_name[start-row : end-row , [col-names-1 , col-names-2]]

airlines.loc[0:10 , ["Airport.Code" , "Month" , "Time.Year"]]
# Out:
#    Airport.Code  Month  Time.Year
# 0           ATL      6       2003
# 1           BOS      6       2003
# 2           BWI      6       2003
# 3           CLT      6       2003
# 4           DCA      6       2003
# 5           DEN      6       2003
# 6           DFW      6       2003
# 7           DTW      6       2003
# 8           EWR      6       2003
# 9           FLL      6       2003
# 10          IAD      6       2003

# %%
### iloc[start : end]

airlines.iloc[12:45]
# Out:
#    Airport.Code                                       Airport.Name Time.Label  \
# 12          JFK        New York, NY: John F. Kennedy International    2003/06
# 13          LAS              Las Vegas, NV: McCarran International    2003/06
# 14          LAX         Los Angeles, CA: Los Angeles International    2003/06
# 15          LGA                            New York, NY: LaGuardia    2003/06
# 16          MCO                 Orlando, FL: Orlando International    2003/06
# 17          MDW          Chicago, IL: Chicago Midway International    2003/06
# 18          MIA                     Miami, FL: Miami International    2003/06
# 19          MSP  Minneapolis, MN: Minneapolis-St Paul Internati...    2003/06
# 20          ORD          Chicago, IL: Chicago O'Hare International    2003/06
# 21          PDX               Portland, OR: Portland International    2003/06
# 22          PHL       Philadelphia, PA: Philadelphia International    2003/06
# ...

# %%
### .iloc[[rows.indexes],[coloumn.indexes]]

airlines.iloc[[0,1,2],[0,5]]
# Out:
#   Airport.Code  Time.Year
# 0          ATL       2003
# 1          BOS       2003
# 2          BWI       2003

# %%
cg = pd.read_csv("university.csv")
cg
# Out:
#    CollegeID                CollegeName      City State  EstablishedYear  \
# 0       1001          Summit University   Boulder    CO             1902
# 1       1002          Ridgeview College  Portland    OR             1955
# 2       1003             Lakefront Tech       NaN    CA             1981
# 3       1004           Metropolis State   Chicago    IL             1899
# 4       1005      Avalon Arts Institute  New York   NaN             2005
# 5       1006  Pioneer Community College    Austin    TX             1973
# 6       1007         Northern Technical    Boston    MA             1968
# 7       1008       Crestwood University       NaN    NY             1924
#
#    Tuition  Enrollment             Website
# 0  45000.0     12000.0      www.summit.edu
# 1      NaN     22000.0   www.ridgeview.edu
# 2  38000.0      8500.0                 NaN
# 3  29500.0         NaN  www.metrostate.edu
# 4      NaN      3200.0  www.avalonarts.org
# 5   8500.0     19500.0    www.pioneercc.tx
# ...

# %%
### top (numbers(index)) of datafram

cg.head(5)
# Out:
#    CollegeID            CollegeName      City State  EstablishedYear  Tuition  \
# 0       1001      Summit University   Boulder    CO             1902  45000.0
# 1       1002      Ridgeview College  Portland    OR             1955      NaN
# 2       1003         Lakefront Tech       NaN    CA             1981  38000.0
# 3       1004       Metropolis State   Chicago    IL             1899  29500.0
# 4       1005  Avalon Arts Institute  New York   NaN             2005      NaN
#
#    Enrollment             Website
# 0     12000.0      www.summit.edu
# 1     22000.0   www.ridgeview.edu
# 2      8500.0                 NaN
# 3         NaN  www.metrostate.edu
# 4      3200.0  www.avalonarts.org

# %%
### bottom (numbers(index)) of datafram

cg.tail(5)
# Out:
#    CollegeID                CollegeName      City State  EstablishedYear  \
# 3       1004           Metropolis State   Chicago    IL             1899
# 4       1005      Avalon Arts Institute  New York   NaN             2005
# 5       1006  Pioneer Community College    Austin    TX             1973
# 6       1007         Northern Technical    Boston    MA             1968
# 7       1008       Crestwood University       NaN    NY             1924
#
#    Tuition  Enrollment             Website
# 3  29500.0         NaN  www.metrostate.edu
# 4      NaN      3200.0  www.avalonarts.org
# 5   8500.0     19500.0    www.pioneercc.tx
# 6  32000.0      7800.0                 NaN
# 7  51000.0      9100.0   www.crestwood.edu

# %%
cg
# Out:
#    CollegeID                CollegeName      City State  EstablishedYear  \
# 0       1001          Summit University   Boulder    CO             1902
# 1       1002          Ridgeview College  Portland    OR             1955
# 2       1003             Lakefront Tech       NaN    CA             1981
# 3       1004           Metropolis State   Chicago    IL             1899
# 4       1005      Avalon Arts Institute  New York   NaN             2005
# 5       1006  Pioneer Community College    Austin    TX             1973
# 6       1007         Northern Technical    Boston    MA             1968
# 7       1008       Crestwood University       NaN    NY             1924
#
#    Tuition  Enrollment             Website
# 0  45000.0     12000.0      www.summit.edu
# 1      NaN     22000.0   www.ridgeview.edu
# 2  38000.0      8500.0                 NaN
# 3  29500.0         NaN  www.metrostate.edu
# 4      NaN      3200.0  www.avalonarts.org
# 5   8500.0     19500.0    www.pioneercc.tx
# ...

# %%
### will remove row data if any null value occures form the CSV file

drop_cg = pd.read_csv("university.csv")
dropped_cg = drop_cg.dropna()


dropped_cg
# Out:
#    CollegeID                CollegeName     City State  EstablishedYear  \
# 0       1001          Summit University  Boulder    CO             1902
# 5       1006  Pioneer Community College   Austin    TX             1973
#
#    Tuition  Enrollment           Website
# 0  45000.0     12000.0    www.summit.edu
# 5   8500.0     19500.0  www.pioneercc.tx

# %%
inplace_cg = cg.dropna(inplace = True)

print(cg.to_string())
# Out:
#    CollegeID                CollegeName     City State  EstablishedYear  Tuition  Enrollment           Website
# 0       1001          Summit University  Boulder    CO             1902  45000.0     12000.0    www.summit.edu
# 5       1006  Pioneer Community College   Austin    TX             1973   8500.0     19500.0  www.pioneercc.tx

# %%
cg
# Out:
#    CollegeID                CollegeName     City State  EstablishedYear  \
# 0       1001          Summit University  Boulder    CO             1902
# 5       1006  Pioneer Community College   Austin    TX             1973
#
#    Tuition  Enrollment           Website
# 0  45000.0     12000.0    www.summit.edu
# 5   8500.0     19500.0  www.pioneercc.tx

# %%
uni = pd.read_csv("new-uni.csv")
uni
# Out:
#             UniversityID                     UniversityName            City  \
# 0                      1             Springfield University     Springfield
# 1                      2                  Riverside College       Riverside
# 2                      3                Maplewood Institute         Toronto
# 3   4Kingston University                             London             NaN
# 4                      5             Summit Peak University          Denver
# 5                      6          Bayside Technical College          Sydney
# 6                      7              Université de la Lune           Paris
# 7                      8                 Green Valley State      Burlington
# 8                      9                 Redwood University       Palo Alto
# 9                     10         Northern Lights University            Oslo
# 10                    11                   Ironwood College      Pittsburgh
# ...

# %%
# uni.isnull()

# %%
### column wise list of null values

uni.isnull().sum().sum()
# Out:
# np.int64(19)

# %%
tot_nulls = uni.isna().sum().sum()

tot_nulls
# Out:
# np.int64(19)

# %%
import pandas as pd

uni = pd.read_csv("new-uni.csv")
uni
# Out:
#             UniversityID                     UniversityName            City  \
# 0                      1             Springfield University     Springfield
# 1                      2                  Riverside College       Riverside
# 2                      3                Maplewood Institute         Toronto
# 3   4Kingston University                             London             NaN
# 4                      5             Summit Peak University          Denver
# 5                      6          Bayside Technical College          Sydney
# 6                      7              Université de la Lune           Paris
# 7                      8                 Green Valley State      Burlington
# 8                      9                 Redwood University       Palo Alto
# 9                     10         Northern Lights University            Oslo
# 10                    11                   Ironwood College      Pittsburgh
# ...

# %%
rows_one_null = uni[uni.isnull().sum(axis=1) == 1]
print(uni.isnull().sum(axis=1) == 1)
rows_one_null

rows_multi_null = uni[uni.isnull().sum(axis=1) >= 1]
rows_multi_null
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13     True
# 14     True
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20     True
# 21    False
# 22    False
# 23     True
# 24    False
# 25     True
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32     True
# 33    False
# 34     True
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40     True
# 41    False
# 42     True
# 43    False
# 44    False
# 45     True
# 46     True
# 47     True
# 48    False
# 49    False
# dtype: bool
#             UniversityID                     UniversityName        City State  \
# 3   4Kingston University                             London         NaN    UK
# 6                      7              Université de la Lune       Paris   NaN
# ...
