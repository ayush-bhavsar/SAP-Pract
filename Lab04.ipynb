# %%
import numpy as np
import pandas as pd

### filtering indexing and grouping

df = pd.read_csv("airlines.csv")
df
# Out:
#      Airport.Code                                       Airport.Name  \
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 1844          MDW          Chicago, IL: Chicago Midway International
# 1845          MIA                     Miami, FL: Miami International
# 1846          MSP  Minneapolis, MN: Minneapolis-St Paul Internati...
# 1847          ORD          Chicago, IL: Chicago O'Hare International
# 1848          PDX               Portland, OR: Portland International
#
#      Time.Label  Month Time.Month Name  Time.Year  \
# 0       2003/06      6            June       2003
# ...

# %%
### rows by coloumns
print(df.shape)
# Out:
# (1849, 24)

# %%
### list down the columns
print(df.columns)
# Out:
# Index(['Airport.Code', 'Airport.Name', 'Time.Label', 'Month',
#        'Time.Month Name', 'Time.Year', 'Statistics.# of Delays.Carrier',
#        'Statistics.# of Delays.Late Aircraft',
#        'Statistics.# of Delays.National Aviation System',
#        'Statistics.# of Delays.Security', 'Statistics.# of Delays.Weather',
#        'Statistics.Carriers.Names', 'Statistics.Carriers.Total', 'Cancelled',
#        'Statistics.Flights.Delayed', 'Statistics.Flights.Diverted',
#        'Statistics.Flights.On Time', 'Statistics.Flights.Total',
#        'Statistics.Minutes Delayed.Carrier',
#        'Statistics.Minutes Delayed.Late Aircraft',
#        'Statistics.Minutes Delayed.National Aviation System',
#        'Statistics.Minutes Delayed.Security',
#        'Statistics.Minutes Delayed.Total',
#        'Statistics.Minutes Delayed.Weather'],
#       dtype='object')

# %%
### access individual coloumns

df[['Airport.Code' , 'Airport.Name']]
# Out:
#      Airport.Code                                       Airport.Name
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 1844          MDW          Chicago, IL: Chicago Midway International
# 1845          MIA                     Miami, FL: Miami International
# 1846          MSP  Minneapolis, MN: Minneapolis-St Paul Internati...
# 1847          ORD          Chicago, IL: Chicago O'Hare International
# 1848          PDX               Portland, OR: Portland International
#
# [1849 rows x 2 columns]

# %%
### shows the 

df['Airport.Code'] == "ATL"
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1844    False
# 1845    False
# 1846    False
# 1847    False
# 1848    False
# Name: Airport.Code, Length: 1849, dtype: bool

# %%
### 

df['Airport.Code'].unique()
# Out:
# array(['ATL', 'BOS', 'BWI', 'CLT', 'DCA', 'DEN', 'DFW', 'DTW', 'EWR',
#        'FLL', 'IAD', 'IAH', 'JFK', 'LAS', 'LAX', 'LGA', 'MCO', 'MDW',
#        'MIA', 'MSP', 'ORD', 'PDX', 'PHL', 'PHX', 'SAN', 'SEA', 'SFO',
#        'SLC', 'TPA'], dtype=object)

# %%
### data filteration finding data for code BOL

df['Airport.Code'] == 'BOS'
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1844    False
# 1845    False
# 1846    False
# 1847    False
# 1848    False
# Name: Airport.Code, Length: 1849, dtype: bool

# %%
### storing the condition into variable and printing it for filtering the records
filter = df['Airport.Code'] == 'BOS' 

## filter variable id needed to passed into df otherwise it will return a boolen array
df[filter]
# Out:
#      Airport.Code                     Airport.Name Time.Label  Month  \
# 1             BOS  Boston, MA: Logan International    2003/06      6
# 30            BOS  Boston, MA: Logan International    2003/07      7
# 59            BOS  Boston, MA: Logan International    2003/08      8
# 88            BOS  Boston, MA: Logan International    2003/09      9
# 117           BOS  Boston, MA: Logan International    2003/10     10
# ...           ...                              ...        ...    ...
# 1712          BOS  Boston, MA: Logan International    2008/05      5
# 1741          BOS  Boston, MA: Logan International    2008/06      6
# 1770          BOS  Boston, MA: Logan International    2008/07      7
# 1799          BOS  Boston, MA: Logan International    2008/08      8
# 1828          BOS  Boston, MA: Logan International    2008/09      9
#
#      Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 1               June       2003                             374
# ...

# %%
new_filter = df['Airport.Code'] == "PDX"

df[new_filter]
# Out:
#      Airport.Code                          Airport.Name Time.Label  Month  \
# 21            PDX  Portland, OR: Portland International    2003/06      6
# 50            PDX  Portland, OR: Portland International    2003/07      7
# 79            PDX  Portland, OR: Portland International    2003/08      8
# 108           PDX  Portland, OR: Portland International    2003/09      9
# 137           PDX  Portland, OR: Portland International    2003/10     10
# ...           ...                                   ...        ...    ...
# 1732          PDX  Portland, OR: Portland International    2008/05      5
# 1761          PDX  Portland, OR: Portland International    2008/06      6
# 1790          PDX  Portland, OR: Portland International    2008/07      7
# 1819          PDX  Portland, OR: Portland International    2008/08      8
# 1848          PDX  Portland, OR: Portland International    2008/09      9
#
#      Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# ...

# %%
### value_count is a mtd to count the catagori
### analys and present the data

df['Airport.Code'] == 'PDX'.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 4
#       1 ### value_count is a mtd to count the catagori
#       2 ### analys and present the data
# ----> 4 df['Airport.Code'] == 'PDX'.value_counts()
#
# AttributeError: 'str' object has no attribute 'value_counts'

# %%
df['Airport.Code'] == 'PDX'.value_counts()

new_filter.value_counts()
print(new_filter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df['Airport.Code'] == 'PDX'.nunique()
#
# AttributeError: 'str' object has no attribute 'nunique'

# %%
### returns top 5 records
df.head()
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0      6            June       2003                            1009
# 1      6            June       2003                             374
# 2      6            June       2003                             296
# 3      6            June       2003                             300
# 4      6            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  \
# 0                                  1275
# ...

# %%
### indexer
## loc and iloc

### start end step [row , col]
df.iloc[0:40:5,0:100:10]
# Out:
#    Airport.Code  Statistics.# of Delays.Weather  \
# 0           ATL                             328
# 5           DEN                              98
# 10          IAD                              66
# 15          LGA                              94
# 20          ORD                             157
# 25          SEA                              36
# 30          BOS                              61
# 35          DFW                             244
#
#     Statistics.Minutes Delayed.National Aviation System
# 0                                              118831
# 5                                               23538
# 10                                              25807
# 15                                              41007
# 20                                             135851
# 25                                              13860
# 30                                              26923
# 35                                              80740

# %%
### in loc col can be accessed using col name only

df.loc[100:200: , ["Airport.Name" , "Airport.Code" , "Time.Label"]]
# Out:
#                                        Airport.Name Airport.Code Time.Label
# 100           Las Vegas, NV: McCarran International          LAS    2003/09
# 101      Los Angeles, CA: Los Angeles International          LAX    2003/09
# 102                         New York, NY: LaGuardia          LGA    2003/09
# 103              Orlando, FL: Orlando International          MCO    2003/09
# 104       Chicago, IL: Chicago Midway International          MDW    2003/09
# ..                                              ...          ...        ...
# 196    Philadelphia, PA: Philadelphia International          PHL    2003/12
# 197   Phoenix, AZ: Phoenix Sky Harbor International          PHX    2003/12
# 198          San Diego, CA: San Diego International          SAN    2003/12
# 199       Seattle, WA: Seattle/Tacoma International          SEA    2003/12
# 200  San Francisco, CA: San Francisco International          SFO    2003/12
#
# [101 rows x 3 columns]

# %%
### slicing could be done by accessing the col name

df.loc[100:200: , "Airport.Name" : "Month" : ]
# Out:
#                                        Airport.Name Time.Label  Month
# 100           Las Vegas, NV: McCarran International    2003/09      9
# 101      Los Angeles, CA: Los Angeles International    2003/09      9
# 102                         New York, NY: LaGuardia    2003/09      9
# 103              Orlando, FL: Orlando International    2003/09      9
# 104       Chicago, IL: Chicago Midway International    2003/09      9
# ..                                              ...        ...    ...
# 196    Philadelphia, PA: Philadelphia International    2003/12     12
# 197   Phoenix, AZ: Phoenix Sky Harbor International    2003/12     12
# 198          San Diego, CA: San Diego International    2003/12     12
# 199       Seattle, WA: Seattle/Tacoma International    2003/12     12
# 200  San Francisco, CA: San Francisco International    2003/12     12
#
# [101 rows x 3 columns]

# %%
### change the name of col

df.rename(columns = {'Airport.Code' : 'Airport_Code'} , inplace=True)

# %%
### this will save the updated col name into `my_data.csv`

df.to_csv("my_data.csv")

# %%
### grouping
### req -1 : col should  be catagorical


nba = pd.read_csv('nba.csv')
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
# 457   True   True    True      True   True    True    True     True    True
#
# [458 rows x 9 columns]

# %%
nba.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
### q1 find the recods having null value

# %%
### grouping

result = nba.groupby('College')
result

# %%
nba['College'].unique()
# Out:
# array(['Texas', 'Marquette', 'Boston University', 'Georgia State', nan,
#        'LSU', 'Gonzaga', 'Louisville', 'Oklahoma State', 'Ohio State',
#        'Washington', 'Kentucky', 'North Carolina', 'Arizona',
#        'Georgia Tech', 'Cincinnati', 'Miami (FL)', 'Stanford', 'Syracuse',
#        'Saint Louis', 'Kansas', 'Georgetown', 'Texas A&M', 'UCLA', 'UNLV',
#        'Wichita State', "Saint Joseph's", 'Notre Dame', 'Norfolk State',
#        'Duke', 'Murray State', 'Tennessee State', 'Bowling Green',
#        'Purdue', 'Wake Forest', 'Michigan', 'Missouri', 'USC',
#        'Villanova', 'Rider', 'Utah', 'Belmont', 'Davidson', 'Vanderbilt',
#        'Michigan State', 'Florida', 'Washington State', 'Arizona State',
#        'Oklahoma', 'Wyoming', "St. John's", 'Maryland', 'Wisconsin',
#        'Utah Valley', 'North Carolina State', 'UC Santa Barbara',
#        'Baylor', 'Connecticut', 'Oregon State', 'New Mexico', 'Oregon',
# ...

# %%
ab = result.get_group("Texas")
ab
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 0        Avery Bradley         Boston Celtics     0.0       PG  25.0    6-2
# 66         Cory Joseph        Toronto Raptors     6.0       PG  24.0    6-3
# 133        P.J. Tucker           Phoenix Suns    17.0       SF  31.0    6-6
# 179   Tristan Thompson    Cleveland Cavaliers    13.0        C  25.0    6-9
# 208       Myles Turner         Indiana Pacers    33.0       PF  20.0   6-11
# 289    Jordan Hamilton   New Orleans Pelicans    25.0       SG  25.0    6-7
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
# 384      D.J. Augustin         Denver Nuggets    12.0       PG  28.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
#
#      Weight College      Salary
# 0     180.0   Texas   7730337.0
# 66    190.0   Texas   7000000.0
# 133   245.0   Texas   5500000.0
# 179   238.0   Texas  14260870.0
# 208   243.0   Texas   2357760.0
# ...

# %%
result["Age"].mean()
# Out:
# College
# Alabama             29.000000
# Arizona             27.384615
# Arizona State       27.500000
# Arkansas            27.333333
# Baylor              25.000000
#                       ...
# Western Michigan    25.000000
# Wichita State       25.000000
# Wisconsin           25.800000
# Wyoming             23.000000
# Xavier              35.000000
# Name: Age, Length: 118, dtype: float64

# %%
max_sal = result["Salary"].max()

# %%
min_sal = result["Salary"].min()

# %%
diff = max_sal - min_sal
diff
# Out:
# College
# Alabama              1254941.0
# Arizona             11504264.0
# Arizona State       15644994.0
# Arkansas             6224592.0
# Baylor                     0.0
#                        ...
# Western Michigan           0.0
# Wichita State              0.0
# Wisconsin            3528353.0
# Wyoming                    0.0
# Xavier                     0.0
# Name: Salary, Length: 118, dtype: float64
