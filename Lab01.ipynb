# %%
### lab 01 Python Basics

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 5
b = 10
add = a+b
print(add)
# Out:
# 15

# %%
def add(a,b):
    return a+b

# %%
add(a,b)
# Out:
# 15

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a = "Ayush"

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
a = 10.0
print(type(a))
# Out:
# <class 'float'>
