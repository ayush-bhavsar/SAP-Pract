# %%
import pandas as pd

# %%
pip install lux
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lux as lx

# %%
df = pd.DataFrame({
    "age": [18, 22, 25, 30, 40],
    "salary": [15000, 22000, 26000, 35000, 50000],
    "city": ["A", "B", "A", "C", "B"]
})

df
# Out:
#    age  salary city
# 0   18   15000    A
# 1   22   22000    B
# 2   25   26000    A
# 3   30   35000    C
# 4   40   50000    B

# %%
df = pd.read_csv("airlines.csv")
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 df = pd.read_csv("airlines.csv")
#       2 df
# ----> 4 new = df.intent["Month"]
#       5 new
#
# TypeError: list indices must be integers or slices, not str
