# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.0 MB 7.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.1/11.0 MB 7.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.7/11.0 MB 7.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.0 MB 7.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/11.0 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.0 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 7.5 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
# ...

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.1 MB 7.7 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/8.1 MB 7.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 7.7 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.1 MB 7.7 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 7.4 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----------------------- ---------------- 1.3/2.3 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 7.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------- -------------------------------- 1.3/7.0 MB 7.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.9/7.0 MB 7.7 MB/s eta 0:00:01
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
may_flights = flights.query("month == 'May'")

sns.lineplot(data = may_flights , x="year" , y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.countplot(data=iris , x="species")
plt.show()

# %%
taxies = sns.load_dataset("taxis")
taxies

sns.countplot(data = taxies , x="color")
# Out:
# <Axes: xlabel='color', ylabel='count'>

# %%
taxies
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
### data passed in hue is catagorical


### months are overlapping there fore a vertical line is displayed in the middle
sns.barplot(data = flights, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.barplot(data=flights[flights["month"].isin(["Jan", "Feb"])],x="year", y="passengers", hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>
